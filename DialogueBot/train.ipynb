# %%
# !pip install tensorflow-gpu

# %%
# !rm -r DialogueBot
# !git clone https://github.com/ressay/DialogueBot.git

# %%
# !pip install rdflib

# %%
# !pip install -r DialogueBot/requirements.txt

# %%
# !mkdir my_weights

# %%
import sys
sys.path.insert(0, ".")
from DialogueManager.FileBrowserDM.agent import AgentFB
from DialogueManager.FileBrowserDM.user_simulator import UserSimulatorFB
from DialogueManager.FileBrowserDM.file_tree_sim import FileTreeSimulator
from DialogueManager.FileBrowserDM.nlg import Nlg_system
from DialogueManager.error_model_controller import ErrorModelController
import Ontologies.onto_fbrowser as fbrowser
import argparse, json
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
CONSTANTS_FILE_PATH = 'DialogueManager/FileBrowserDM/constants.json'
constants_file = CONSTANTS_FILE_PATH

consts = {
  "run": {
    "usersim": True,
    "warmup_mem": 1000,
    "num_ep_run": 1500,
    "train_freq": 100,
    "max_round_num": 40,
    "success_rate_threshold": 0.3
  },
  "agent": {
    "save_weights_file_path": "my_weights/m.h5",
    "load_weights_file_path": 0,
    "vanilla": True,
    "learning_rate": 1e-3,
    "batch_size": 128,
    "dqn_hidden_size": 80,
    "epsilon_init": 0.5,
    "gamma": 0.7,
    "max_mem_size": 50000,
    "agent_actions": ["Create_file","Delete_file","Change_directory",
      "inform","ask","request"]
  },
  "emc": {
    "slot_error_mode": 0,
    "slot_error_prob": 0.3,
    "intent_error_prob": 0.1
  }
}
with open(constants_file, 'w') as f:
  json.dump(consts, f)

# %%
CONSTANTS_FILE_PATH = 'DialogueManager/FileBrowserDM/constants.json'
constants_file = CONSTANTS_FILE_PATH

with open(constants_file) as f:
  constants = json.load(f)

# Load run constants
run_dict = constants['run']
USE_USERSIM = run_dict['usersim']
WARMUP_MEM = run_dict['warmup_mem']
NUM_EP_TRAIN = run_dict['num_ep_run']
TRAIN_FREQ = run_dict['train_freq']
MAX_ROUND_NUM = run_dict['max_round_num']
SUCCESS_RATE_THRESHOLD = run_dict['success_rate_threshold']
compress = True
train_batch = True
use_encoder = True
one_hot = True

# Init. Objects
user = UserSimulatorFB(constants,fbrowser.graph)

error_infuser = ErrorModelController(constants)
all_actions = []
all_trees = []

# %%
def rm_keys(action):
    a = {}
    for key in ['intent', 'file_name', 'slot', 'new_directory', 'path',
                'origin', 'dest', 'error', 'old_name', 'new_name', 'slot']:
        if key in action:
            a[key] = action[key]
    return a
            

def run_round(user):
    # 1) Agent takes action given state tracker's representation of dialogue (state)
#     print('running round')
#     user.state['current_file_tree'].print_tree()
#     dqn_agent.state_tracker.get_data()['current_tree_sim'].print_tree()
    state = dqn_agent.get_state()
    
    try:
        agent_action_index, agent_action = dqn_agent.step()
        user_action, reward, done, success = user.step(agent_action)
        error_infuser.infuse_error(user_action)
        dqn_agent.update_state_user_action(user_action)
    except Exception as e:
        user.state['current_file_tree'].print_tree()
        dqn_agent.state_tracker.get_data()['current_tree_sim'].print_tree()
        for acts,trees in zip(all_actions,all_trees):
            a, u = acts
            u = rm_keys(u)
            a = rm_keys(a)
            print(a)
            print(u)
            t1,t2 = trees
            t1.print_tree()
            t2.print_tree()
        print(agent_action)
        print(user_action)
        raise e
    

        
    # if not done:
        # 4) Infuse error into semantic frame level of user action
        # emc.infuse_error(user_action)
    # 5) Update state tracker with user action
    
    
    all_actions.append((agent_action, user_action))
    all_trees.append((user.state['current_file_tree'].copy(),
                    dqn_agent.state_tracker.get_data()['current_tree_sim'].copy()))
    tuser1, tagent2 = all_trees[-1]
    f, t = tuser1.tree_similarity(tagent2)
    if f != t and user_action['intent'] != 'end':
        print('not similar! ', f, t)
        print('prev:')
        tt1, tt2 = all_trees[-2]
        tt1.print_tree()
        tt2.print_tree()
        print(tt1.tree_map)
        print(tt2.tree_map)
        a, u = all_actions[-1]
        u = rm_keys(u)
        a = rm_keys(a)
        print(a)
        print(u)
        tuser1.print_tree()
        tagent2.print_tree()
        print(tuser1.tree_map)
        print(tagent2.tree_map)
        print('all_actions:', len(all_actions))
        for a, u in all_actions:
            u = rm_keys(u)
            a = rm_keys(a)
            print(a)
            print(u)
    # state_tracker.update_state_user(user_action)
    # 6) Get next state and add experience
    next_state = dqn_agent.get_state()
    # next_state = state_tracker.get_state(done)
    dqn_agent.add_experience(state, agent_action_index, reward, next_state, done)

    return reward, done, success


def train_run():
    """
    Runs the loop that trains the agent.
    Trains the agent on the goal-oriented chatbot task. Training of the agent's neural network occurs every episode that
    TRAIN_FREQ is a multiple of. Terminates when the episode reaches NUM_EP_TRAIN.
    """
    print('Training Started...')
    
    success_rate_best = 0.99
    episode = 0
    avg_tree_size_succeeded = 0.0
    tree_sizes = []
    ftree_sizes = []
    period_reward_total = 0
    period_reward_success = 0
    period_success_total = 0      
    start_eps = 0.5
    while episode < NUM_EP_TRAIN:
        user = episode_reset()
        episode += 1
        # print('running episode:',episode)
        done = False
        # state = state_tracker.get_state()
        r_sum = 0
        while not done:
            reward, done, success = run_round(user)
            period_reward_total += reward
            r_sum += reward
              

        # print('success is: ',success)
        period_success_total += success
        period_reward_success += r_sum*success
        rsize = user.goal['goal_tree'].r_size()
        if success == 1:
          tree_sizes.append(rsize)
        else:
          ftree_sizes.append(rsize)

        # Train
        if episode % TRAIN_FREQ == 0:

            # Check success rate
            success_rate = period_success_total / TRAIN_FREQ
            
            success_rates.append(success_rate)
            df = pd.DataFrame(success_rates, columns=["success_rates"])
            df.to_csv('success_rates_per_100.csv')
            step = 0.05
            if success_rate > 0.7:
                if dqn_agent.eps > 0:
                    dqn_agent.eps -= step
                if dqn_agent.eps <= 0.005:
                    dqn_agent.eps = 0.005
            else:
                dqn_agent.eps = start_eps*(1 - success_rate)
            
            avg_reward = period_reward_total / TRAIN_FREQ
            avg_success_reward = period_reward_success / max((period_success_total,1))
            if not len(tree_sizes): tree_sizes = [1]
            if not len(ftree_sizes): ftree_sizes = [1]
            print('training after getting success_rate:', success_rate, " and avg_reward: ",avg_reward, " avg success reward ", avg_success_reward,
                  " max tree size: ",max(tree_sizes)," avg size: ",float(sum(tree_sizes))/max((1,len(tree_sizes))),
                  " avg failure size: ", float(sum(ftree_sizes))/max((1,len(ftree_sizes))), " min failure size: ",min(ftree_sizes))
            
            # Update current best success rate
            
            # Flush
#             if success_rate > success_rate_best and success_rate >= SUCCESS_RATE_THRESHOLD:
#                 dqn_agent.empty_memory()
#                 period_reward_total = 0
#                 period_success_total = 0
#                 period_reward_success = 0
#                 avg_tree_size_succeeded = 0.0
#                 tree_sizes = []
#                 success_rate_best = success_rate
#                 dqn_agent.save_weights()
#                 continue
#             period_success_total = 0
#             period_reward_total = 0
            if success_rate > success_rate_best:
                # print('Episode: {} NEW BEST SUCCESS RATE: {} Avg Reward: {}' .format(episode, success_rate, avg_reward))
                success_rate_best = success_rate
                dqn_agent.save_weights()
#                 uploaded = drive.CreateFile({'title': 'm_beh.h5'})
#                 uploaded.SetContentFile('my_weights/m_beh.h5')
#                 uploaded.Upload()
#                 print('Uploaded file with ID {}'.format(uploaded.get('id')))
          
            period_reward_total = 0
            period_success_total = 0
            period_reward_success = 0
            avg_tree_size_succeeded = 0.0
            tree_sizes = []
            ftree_sizes = []
            # Copy
            dqn_agent.copy()
            # Train
            dqn_agent.train()
            
    print('...Training Ended')


def episode_reset():
    """
    Resets the episode/conversation in the warmup and training loops.
    Called in warmup and train to reset the state tracker, user and agent. Also gets the initial user action.
    """
#     user = UserSimulatorFB(constants,fbrowser.graph)
    all_actions.clear()
    all_trees.clear()
    tree_sim = FileTreeSimulator()
    data = {'current_tree_sim': tree_sim, 'tree_sim': tree_sim}
    user_action = user.reset(data)
    dqn_agent.reset(user_action,data)
    all_trees.append((user.state['current_file_tree'].copy(),
                          dqn_agent.state_tracker.get_data()['current_tree_sim'].copy()))
    return user

# %%
dqn_agent.get_state_output = dqn_agent._build_state_model(dqn_agent.beh_model)
dqn_agent.get_state_and_action = dqn_agent._built_state_action_model(dqn_agent.beh_model)

# %%
dqn_agent.eps = 0

# %%
success_rates = []
dqn_agent = AgentFB(50, constants,train_batch, use_encoder, compress,one_hot)
train_run()
# Out:
# Training Started...
# training after getting success_rate: 0.05  and avg_reward:  -10.243500000000001  avg success reward  -0.25  max tree size:  3  avg size:  1.8  avg failure size:  4.821052631578947  min failure size:  0
# Epoch 1/1
# 24/24 [==============================] - 3s 120ms/step - loss: 0.5895
# finished fitting on  2310  samples and avg triplet number:  0.0
# training after getting success_rate: 0.04  and avg_reward:  -5.5095  avg success reward  -0.125  max tree size:  4  avg size:  2.75  avg failure size:  4.90625  min failure size:  0
# Epoch 1/1
# 49/49 [==============================] - 4s 76ms/step - loss: 0.2642
# finished fitting on  4458  samples and avg triplet number:  0.0
# training after getting success_rate: 0.07  and avg_reward:  -4.976500000000001  avg success reward  -1.8928571428571428  max tree size:  4  avg size:  2.7142857142857144  avg failure size:  4.451612903225806  min failure size:  0
# Epoch 1/1
# 75/75 [==============================] - 6s 76ms/step - loss: 0.2428
# finished fitting on  7214  samples and avg triplet number:  0.0
# training after getting success_rate: 0.1  and avg_reward:  -3.9385000000000003  avg success reward  0.55  max tree size:  6  avg size:  3.4  avg failure size:  4.388888888888889  min failure size:  0
# Epoch 1/1
# 97/97 [==============================] - 8s 78ms/step - loss: 0.2145
# finished fitting on  9400  samples and avg triplet number:  0.0
# training after getting success_rate: 0.1  and avg_reward:  -4.112  avg success reward  1.525  max tree size:  6  avg size:  3.7  avg failure size:  4.5  min failure size:  1
# Epoch 1/1
# 123/123 [==============================] - 9s 76ms/step - loss: 0.1946
# finished fitting on  11342  samples and avg triplet number:  0.0
# training after getting success_rate: 0.14  and avg_reward:  -4.7540000000000004  avg success reward  2.0357142857142856  max tree size:  5  avg size:  3.357142857142857  avg failure size:  5.3604651162790695  min failure size:  1
# Epoch 1/1
# 146/146 [==============================] - 14s 94ms/step - loss: 0.1815
# finished fitting on  13875  samples and avg triplet number:  0.0
# training after getting success_rate: 0.04  and avg_reward:  -4.621500000000001  avg success reward  1.0  max tree size:  3  avg size:  2.5  avg failure size:  4.96875  min failure size:  1
# Epoch 1/1
# 172/172 [==============================] - 15s 89ms/step - loss: 0.1652
# finished fitting on  17120  samples and avg triplet number:  0.0
# training after getting success_rate: 0.16  and avg_reward:  -3.8140000000000014  avg success reward  2.609375  max tree size:  6  avg size:  3.4375  avg failure size:  5.333333333333333  min failure size:  2
# Epoch 1/1
# 196/196 [==============================] - 21s 106ms/step - loss: 0.1413
# finished fitting on  18865  samples and avg triplet number:  0.0
# training after getting success_rate: 0.16  and avg_reward:  -3.786000000000001  avg success reward  0.78125  max tree size:  8  avg size:  2.875  avg failure size:  5.119047619047619  min failure size:  1
# Epoch 1/1
# 221/221 [==============================] - 20s 93ms/step - loss: 0.1557
# finished fitting on  21860  samples and avg triplet number:  0.0
# training after getting success_rate: 0.19  and avg_reward:  -3.759  avg success reward  0.7973684210526315  max tree size:  9  avg size:  3.4210526315789473  avg failure size:  4.580246913580247  min failure size:  0
# Epoch 1/1
# 244/244 [==============================] - 24s 98ms/step - loss: 0.1490
# finished fitting on  24030  samples and avg triplet number:  0.0
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8b70>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8c50>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552587c588>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552587cda0>, 'name': 'dir4'})}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550ef5b828>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550ef5b4a8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ffe48>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c24d518>, 'name': 'dir4'})}
# all_actions: 5
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550ef5b828>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550ef5b4a8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ffe48>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c24d518>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff518>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff5c0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8080>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f80f0>, 'name': 'dir4'})}
# all_actions: 6
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff518>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff5c0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8080>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f80f0>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252725c0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272dd8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252722e8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272f98>, 'name': 'dir4'})}
# all_actions: 7
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252725c0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272dd8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252722e8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272f98>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272ba8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272ef0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d400>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542da20>, 'name': 'dir4'})}
# all_actions: 8
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272ba8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272ef0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d400>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542da20>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d8d0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d390>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d198>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f941550>, 'name': 'dir4'})}
# all_actions: 9
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d8d0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d390>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d198>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f941550>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542df28>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d3c8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff9b0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8f98>, 'name': 'dir4'})}
# all_actions: 10
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542df28>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d3c8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55258ff9b0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551f2f8f98>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd438>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd3c8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd2e8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cde10>, 'name': 'dir4'})}
# all_actions: 11
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd438>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd3c8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd2e8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cde10>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd588>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cdac8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3860>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3d68>, 'name': 'dir4'})}
# all_actions: 12
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  6 7
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ---> dir1  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir1  parent:  dir1
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd588>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cdac8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3860>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3d68>, 'name': 'dir4'})}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c693fd0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552567a7b8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550efbb4a8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550efbb780>, 'name': 'dir4'})}
# all_actions: 13
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# not similar!  6 7
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c693fd0>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552567a7b8>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550efbb4a8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550efbb780>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2320>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2b70>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cdb00>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd780>, 'name': 'dir4'})}
# all_actions: 14
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  6 7
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2320>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2b70>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cdb00>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd780>, 'name': 'dir4'})}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2a90>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c9087f0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd668>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525c63908>, 'name': 'dir4'})}
# all_actions: 15
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55252d2a90>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c9087f0>, 'name': 'dir4'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cd668>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525c63908>, 'name': 'dir4'})}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272390>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272b70>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272da0>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d4a8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d6a0>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d9b0>, 'name': 'dir4'})}
# all_actions: 16
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272390>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272b70>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272da0>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d4a8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d6a0>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552542d9b0>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272550>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272d30>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272748>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e35f8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3978>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e31d0>, 'name': 'dir4'})}
# all_actions: 17
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272550>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272d30>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525272748>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e35f8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3978>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e31d0>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e37b8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3160>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3e80>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3208>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3438>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3278>, 'name': 'dir4'})}
# all_actions: 18
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e37b8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3160>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3e80>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3208>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3438>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3278>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3908>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2e8fd0>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cda58>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525a5f710>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55255c57b8>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55255c5908>, 'name': 'dir4'})}
# all_actions: 19
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55265e3908>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2e8fd0>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f552c2cda58>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525a5f710>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55255c57b8>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55255c5908>, 'name': 'dir4'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55257390b8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525739550>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55257390f0>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918048>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918710>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918940>, 'name': 'dir4'})}
# all_actions: 20
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir4/dir5'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1'}
# {'intent': 'Delete_file_desire', 'file_name': 'dir1'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'Delete_file', 'file_name': 'dir1', 'path': '~/dir1/'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'Create_file', 'file_name': 'file1', 'path': '~'}
# {'intent': 'Delete_file_desire', 'file_name': 'kzma'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  7 8
# prev:
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# -----> dir1  parent:  dir5
# ---> dir6  parent:  dir4
# -> file1  parent:  ~
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# -> file1  parent:  ~
# -> dir4  parent:  ~
# ---> dir5  parent:  dir4
# ---> dir6  parent:  dir4
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55257390b8>, 'name': 'dir1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525739550>, 'name': 'dir4'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f55257390f0>, 'name': 'file1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918048>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918710>, 'name': 'file1'}), 'dir4': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f5525918940>, 'name': 'dir4'})}
# {'intent': 'default'}
# {'intent': 'Delete_file_desire', 'file_name': 'file1'}
# ~:
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# ---> dir3  parent:  dir1
# ...
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'Change_directory', 'new_directory': '~/dir1'}
# {'intent': 'Change_directory_desire'}
# not similar!  6 7
# prev:
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f67ec18>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550ff2fc18>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0e10>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0160>, 'name': 'file1'})}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0c18>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0b70>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f57cf60>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f57cf98>, 'name': 'file1'})}
# all_actions: 30
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1/dir2'}
# {'intent': 'Create_file_desire', 'file_name': 'dir2'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'confirm', 'file_name': 'gqyo'}
# {'intent': 'Create_file', 'file_name': 'dir2', 'path': '~/dir1/dir2/dir1'}
# {'intent': 'inform', 'slot': 'directory'}
# {'intent': 'request', 'file_name': 'dir2', 'slot': 'parent_directory'}
# {'intent': 'inform'}
# {'intent': 'inform', 'error': FileNameExistsError()}
# {'intent': 'request', 'file_name': 'file3', 'slot': 'directory'}
# {'intent': 'inform', 'file_name': 'file3'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'inform', 'error': PuttingFileUnderRegularFile()}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'directory'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'Change_directory', 'new_directory': '~/dir1'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# not similar!  6 7
# prev:
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0c18>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c3e0b70>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f57cf60>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f57cf98>, 'name': 'file1'})}
# {'intent': 'ask'}
# {'intent': 'deny'}
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfecba8>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfecf28>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551de174a8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c932048>, 'name': 'file1'})}
# all_actions: 31
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1/dir2'}
# {'intent': 'Create_file_desire', 'file_name': 'dir2'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'confirm', 'file_name': 'gqyo'}
# {'intent': 'Create_file', 'file_name': 'dir2', 'path': '~/dir1/dir2/dir1'}
# {'intent': 'inform', 'slot': 'directory'}
# {'intent': 'request', 'file_name': 'dir2', 'slot': 'parent_directory'}
# {'intent': 'inform'}
# {'intent': 'inform', 'error': FileNameExistsError()}
# {'intent': 'request', 'file_name': 'file3', 'slot': 'directory'}
# {'intent': 'inform', 'file_name': 'file3'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'inform', 'error': PuttingFileUnderRegularFile()}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'directory'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'Change_directory', 'new_directory': '~/dir1'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# not similar!  6 7
# prev:
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfecba8>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfecf28>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551de174a8>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c932048>, 'name': 'file1'})}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f5d9c50>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfec4e0>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9e48>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9748>, 'name': 'file1'})}
# all_actions: 32
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1/dir2'}
# {'intent': 'Create_file_desire', 'file_name': 'dir2'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'confirm', 'file_name': 'gqyo'}
# {'intent': 'Create_file', 'file_name': 'dir2', 'path': '~/dir1/dir2/dir1'}
# {'intent': 'inform', 'slot': 'directory'}
# {'intent': 'request', 'file_name': 'dir2', 'slot': 'parent_directory'}
# {'intent': 'inform'}
# {'intent': 'inform', 'error': FileNameExistsError()}
# {'intent': 'request', 'file_name': 'file3', 'slot': 'directory'}
# {'intent': 'inform', 'file_name': 'file3'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'inform', 'error': PuttingFileUnderRegularFile()}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'directory'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'Change_directory', 'new_directory': '~/dir1'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# not similar!  6 7
# prev:
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550f5d9c50>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551dfec4e0>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9e48>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9748>, 'name': 'file1'})}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# ~:
# -> file1  parent:  ~
# -> dir1  parent:  ~
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# -------> dir2  parent:  dir1
# ---> file2  parent:  dir1
# ---> file3  parent:  dir1
# ~:
# -> dir1  parent:  ~
# ---> file3  parent:  dir1
# ---> dir2  parent:  dir1
# -----> dir1  parent:  dir2
# ---> file2  parent:  dir1
# -> file1  parent:  ~
# {'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9d30>, 'name': 'file1'}), 'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f551c6f9c88>, 'name': 'dir1'})}
# {'dir1': (0, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550fc62978>, 'name': 'dir1'}), 'file1': (1, {'tree_sim': <DialogueManager.FileBrowserDM.file_tree_sim.FileTreeSimulator object at 0x7f550fc62390>, 'name': 'file1'})}
# all_actions: 33
# {'intent': 'Create_file', 'file_name': 'dir1', 'path': '~/dir1/dir2'}
# {'intent': 'Create_file_desire', 'file_name': 'dir2'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'confirm', 'file_name': 'gqyo'}
# {'intent': 'Create_file', 'file_name': 'dir2', 'path': '~/dir1/dir2/dir1'}
# {'intent': 'inform', 'slot': 'directory'}
# {'intent': 'request', 'file_name': 'dir2', 'slot': 'parent_directory'}
# {'intent': 'inform'}
# {'intent': 'inform', 'error': FileNameExistsError()}
# {'intent': 'request', 'file_name': 'file3', 'slot': 'directory'}
# {'intent': 'inform', 'file_name': 'file3'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'file_name'}
# {'intent': 'inform', 'file_name': 'file1'}
# {'intent': 'inform', 'error': PuttingFileUnderRegularFile()}
# {'intent': 'Create_file_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'request', 'slot': 'directory'}
# {'intent': 'inform'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'confirm'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'Change_directory', 'new_directory': '~/dir1'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'ask'}
# {'intent': 'deny'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# {'intent': 'default'}
# {'intent': 'Change_directory_desire'}
# training after getting success_rate: 0.28  and avg_reward:  -3.1405000000000007  avg success reward  1.6392857142857142  max tree size:  9  avg size:  3.7857142857142856  avg failure size:  5.319444444444445  min failure size:  1
# Epoch 1/1
# 340/340 [==============================] - 29s 86ms/step - loss: 0.1465
# finished fitting on  30320  samples and avg triplet number:  0.0
# training after getting success_rate: 0.26  and avg_reward:  -2.915  avg success reward  1.5153846153846153  max tree size:  8  avg size:  3.769230769230769  avg failure size:  5.405405405405405  min failure size:  1
# Epoch 1/1
# 365/365 [==============================] - 33s 91ms/step - loss: 0.1418
# finished fitting on  33434  samples and avg triplet number:  0.0
# ...Training Ended

# %%
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Create & upload a file.
uploaded = drive.CreateFile({'title': 'm_beh.h5'})
uploaded.SetContentFile('my_weights/m_beh.h5')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %%
id='18eWGaUMTpqrnjSojPEUZwJp0Vq_UrgAS'
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('my_weights/m_beh.h5')

# %%
def action_str(action):
    newa = {}
    for k in action:
        if k not in ['file_node','action_node']:
            newa[k] = action[k]
    return newa

# %%
nlg_sys = Nlg_system()
def simulate():
    tree_sim = FileTreeSimulator()
    data = {'current_tree_sim': tree_sim, 'tree_sim': tree_sim}
    done = False
    user_action = user.reset(data)
    print('user goal:')
    tree_sim.print_tree()
    user.goal['goal_tree'].print_tree()
    print('user: ', user_action)
    
    dqn_agent.reset(user_action,data)
    while not done:
        agent_action_index, agent_action = dqn_agent.step()
        print('agent: ',nlg_sys.get_sentence(agent_action))
        user_action, reward, done, success = user.step(agent_action)
        print('user: ', user_action)
        dqn_agent.update_state_user_action(user_action)

# %%
dqn_agent.eps = 0

# %%
simulate()

# %%
import matplotlib.pyplot as plt

# %%
x1 = [1,2,3] 
y1 = [2,2,1] 
# plotting the line 1 points  
plt.plot(x1, y1, label = "line 1") 
  
# line 2 points 
x2 = [1,2,3] 
y2 = [4,3,3] 
# plotting the line 2 points  
plt.plot(x2, y2, label = "line 2") 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
# giving a title to my graph 
plt.title('Two lines on same graph!') 
  
# show a legend on the plot 
plt.legend() 
  
# function to show the plot 
# plt.show() 
plt.savefig('foo.png', bbox_inches='tight')

# %%
import pandas as pd
import numpy as np

# %%
episodes = [1,2,3]
success_rate = [0.1,0.4,0.6]
avg_reward = [1,4,10]
data = {
    'episodes': episodes,
    'success_rate': success_rate,
    'avg_reward': avg_reward
}
newpd = pd.DataFrame(data=data)
newpd.to_csv('file.csv')
